# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' #맑은 고딕
matplotlib.rcParams['font.size'] = 15 #글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False #한글 폰트 사용 시 마이너스 글자가 깨지는 현상을 해결

# %%
import pandas as pd
df = pd.read_excel('data/score.xlsx', index_col='지원번호')
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80         NaN
# 5번    강백호  북산고  188   15   20   10  35  10         NaN
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
x = list(df['이름'])
y = list(df['키'])

# %%
max = df['키'].max()
min = df['키'].min()
print(max, min)
# Out:
# 202 168

# %%
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f']
plt.bar(x, y, color=colors, width=0.5)
plt.ylim(min-10, max+10)
plt.xticks(rotation=45)
plt.show()

# %%
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f']
plt.barh(x, y, color=colors)
plt.xlim(min-10, max+10)
plt.show()

# %%
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f']
bar=plt.bar(x, y, color=colors, width=0.5)
bar[0].set_hatch('/')
bar[1].set_hatch('x')
bar[2].set_hatch('..')
plt.ylim(min-10, max+10)
plt.xticks(rotation=90)
for idx, height in enumerate(y):
    plt.text(idx, height+0.5, height, ha='center')
plt.show()

# %%
plt.plot(df['이름'], df['국어'], label='국어')
plt.plot(df['이름'], df['영어'], label='영어')
plt.plot(df['이름'], df['수학'], label='수학')
plt.grid(axis='y', color='green', alpha=0.5, ls='--', lw=2)
plt.legend(ncols=3)
plt.show()

# %%
plt.bar(df['이름'], df['국어'], label='국어')
plt.bar(df['이름'], df['영어'], bottom=df['국어'], label='영어')
plt.bar(df['이름'], df['수학'], bottom=df['국어']+df['영어'], label='수학')
plt.xticks(rotation=90)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 plt.bar(df['이름'], df['국어'], label='국어')
#       2 plt.bar(df['이름'], df['영어'], bottom=df['국어'], label='영어')
#       3 plt.bar(df['이름'], df['수학'], bottom=df['국어']+df['영어'], label='수학')
#
# NameError: name 'plt' is not defined

# %%
plt.bar(df['이름'], df['국어'], label='국어')
plt.bar(df['이름'], df['영어'], bottom=df['국어'], label='영어')
plt.bar(df['이름'], df['수학'], bottom=df['국어']+df['영어'], label='수학')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
import numpy as np
index = np.arange(df.shape[0])

# %%
w = 0.25
plt.figure(figsize=(10, 5))
plt.bar(index-w, df['국어'], width=w, label='국어')
plt.bar(index, df['영어'], width=w, label='영어')
plt.bar(index+w, df['수학'], width=w, label='수학')
plt.xticks(index, df['이름'], rotation=60)
plt.legend(ncols=3)
plt.show()
